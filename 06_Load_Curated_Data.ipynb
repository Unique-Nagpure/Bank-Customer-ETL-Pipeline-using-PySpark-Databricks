# %% [markdown]
# ### Write Curated Data

# %%
df_clean = spark.table("testdatabricksuni.uniqueschema.bank_customer_stage5")

# %%
(df_clean.write
    .mode("overwrite")
    .saveAsTable("testdatabricksuni.`gold-layer-data`.bank_customer_Gold_Layer"))
